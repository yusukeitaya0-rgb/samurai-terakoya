# %% [markdown]
# <a href="https://colab.research.google.com/github/yusukeitaya0-rgb/samurai-terakoya/blob/main/forwhile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#forループで水～冥の9行を表示し、つぎにwhileループで水～冥の9行を表示してください
array = ["水","金","地","火","木","土","天","海","冥"]
for i in array:
  print(i)

#whileループで水～冥の9行を表示してください
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

#変数iが0～9番目まで（1番目”水”から始めて9番目の”冥”まで）

i = 0

while i < 9:
 print(array[i])

#変数iのカウントを1つ足す

 i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
