# %% [markdown]
# <a href="https://colab.research.google.com/github/yusukeitaya0-rgb/samurai-terakoya/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_invoice(amount):
    if amount < 0:
        return "エラー：金額がマイナスです"
    else:
        return "確認完了"

# あとは呼び出すだけ
print(check_invoice(5000))
print(check_invoice(-100))
# Out:
# 確認完了
# エラー：金額がマイナスです
