# %%
"""
【再提出】
商品購入時の消費税を、関数で計算するプログラムのソースコードを作成して提出してください。以下のヒントを参考にして、プログラムを作成してください。
消費税を加えた計算結果を返す関数を記述する
「結果を返す関数」なので戻り値を使用する
第1引数に商品の金額「110」、第2引数に消費税（10%）の「10」を設定する
"""

def add_two_arguments(price, tax):
    # 与えられた引数priceと引数tax（％）を加算し、変数totalに代入する
    total = price + price*(tax/100)
    # 変数totalの戻り値を返す
    return total
#戻り値に引数2つを入力
result = add_two_arguments(110, 10)
 # 変数resultの値を出力する
print(f"{result}円")
# Out:
# 121.0円

# %%
price1 = 100
price2 = 200

tax = 1.1 # Define tax in the global scope

def total():
    # The local 'tax' was causing the NameError if used outside.
    # Now 'tax' is available globally.
    return price1 + price2

print (total() * tax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3535/2435960278.py in <cell line: 0>()
#       6     return price1 + price2
#       7
# ----> 8 print (total() * tax)
#
# NameError: name 'tax' is not defined

# %%
class Product:
    def __init__(self):
        self.name = ""

    # メソッドを定義する
    def set_name(self, name):
        self.name = name

    def show_name(self):
        print(self.name)

# インスタンス化する
coffee = Product()

# メソッドにアクセスして実行する
coffee.set_name("コーヒー")
coffee.show_name()
# Out:
# コーヒー
