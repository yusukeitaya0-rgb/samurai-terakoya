# %% [markdown]
# <a href="https://colab.research.google.com/github/yusukeitaya0-rgb/samurai-terakoya/blob/main/%E3%83%AA%E3%82%B9%E3%83%88%E9%80%A3%E6%83%B3%E9%85%8D%E5%88%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
「array」という名前のリストを以下の内容で作成してください。
リストの順序	リストに入れる文字列
0	月曜日は晴れです
1	火曜日は雨です
2	水曜日は晴れです
3	木曜日は晴れです
4	金曜日は曇りです
5	土曜日は曇りのち雨です
6	日曜日は雷雨です
"""
array=["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです", "木曜日は晴れです", "金曜日は曇りです", "土曜日は曇りのち雨です", "日曜日は雷雨です" ]
print(array[2])

"""
mon	晴れ
tue	雨
wed	晴れ
thu	晴れ
fri	曇り
sat	曇りのち雨
sun	雷雨
"""
dictionary=stationery_prices = {"mon": "晴れ", "tue": "雨","wed": "晴","thu":"晴れ","fri":"曇り","sat":"曇りのち雨","sun":"雷雨"}
print(dictionary)
# Out:
# 水曜日は晴れです
# {'mon': '晴れ', 'tue': '雨', 'wed': '晴', 'thu': '晴れ', 'fri': '曇り', 'sat': '曇りのち雨', 'sun': '雷雨'}
