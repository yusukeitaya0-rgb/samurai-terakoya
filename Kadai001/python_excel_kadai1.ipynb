# %%
"""
固定データ
株式会社ABC
〒101-0022 東京都千代田区神田練塀町300
TEL:03-1234-5678 FAX:03-1234-5678
担当者名:鈴木一郎 様
日付は、現在の日付（年月日） を「2023/06/06」の書式（YYYY/MM/DDのフォーマット）で設定してください。
以下の画像を参考に「請求書_20230520（現在日付）.xlsx」を新規作成するプログラムを記述してください

# セルに値を書き込む（後の節で学習します）
ws['A1'] = 42

# セルに値を書き込む
ws['A1'] = 10

# Excelファイルを別名保存する
workbook.save('sample2.xlsx')

#ファイル名「請求書_20260425（現在日付）.xlsx」にして保存
import openpyxl
# datetimeモジュールのdatetimeクラスをインポートする
from datetime import datetime

for row in data:
    sheet.append(row)
thin_border = Border(left=Side(style='thin'),
                    right=Side(style='thin'),
                    top=Side(style='thin'),
                    bottom=Side(style='thin'))
for row in sheet['A1:D4']:
    for cell in row:
        cell.border = thin_border
"""
import openpyxl
from openpyxl.styles import Border, Side
Workbook = openpyxl.Workbook()

# アクティブなシートを取得する
sheet =   Workbook.active

# セル「A2」に、値「請求書」を入力
sheet['A2'].value = '請求書'
# セル「A4」に、値「株式会社ABC」を入力
sheet['A4'].value = '株式会社ABC'
# セル「A5」に、値「〒101-0022 東京都千代田区神田練塀町300」を入力
sheet['A5'].value = '〒101-0022 東京都千代田区神田練塀町300'
# セル「A6」に、値「TEL:03-1234-5678 FAX:03-1234-5678」を入力
sheet['A6'].value = 'TEL:03-1234-5678 FAX:03-1234-5678'
# セル「A7」に、値「担当者名:鈴木一郎 様」を入力
sheet['A7'].value = '担当者名:鈴木一郎 様'

# セル「E4」に、値「」を入力
sheet['E4'].value = 'No.'
# セル「E5」に、値「日付」を入力
sheet['E5'].value = '日付'

# セル「F4」に、値「」を入力
sheet['F4'].value = '0001'


# セル「F5」に、値「20260425（現在日付）」を入力
# datetimeモジュールのdatetimeクラスをインポートする
from datetime import datetime
today = datetime.today()
sheet['F5'].value = today.strftime('%Y/%m/%d')


#ヘッダー入力
header = ['商品名', '数量', '単価', '金額']
sheet.append(header)

print(sheet)

data = [
    ['商品A', 2, 10000, 20000],
    ['商品B', 1, 15000, 15000],
    ['','','',35000]
    ]
for row in data:
    sheet.append(row)

total = data[0][3] + data[1][3]
tax = total*0.1
tax_total =total + tax

sheet['D13'].value = total
sheet['D14'].value = tax
sheet['D15'].value = tax_total
sheet['A13'].value = '合計'
sheet['A14'].value = '消費税'
sheet['A15'].value = '税込合計'

sheet.insert_cols(0,1)

#ファイル名「請求書_20260425（現在日付）.xlsx」にして保存
import openpyxl
# datetimeモジュールのdatetimeクラスをインポートする
from datetime import datetime

# 現在の日付（年月日）を取得して、変数todayに代入する
today = datetime.today()
# 日付のtodayオブジェクトを、特定のフォーマットで文字列に変換する
backup_filename = f"請求書_{today.strftime('%Y%m%d')}.xlsx"

Workbook.save(backup_filename)
# Out:
# <Worksheet "Sheet">
